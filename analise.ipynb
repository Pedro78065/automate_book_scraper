# %%
import pandas as pd

df = pd.read_csv('produtos.csv', sep=',')
display(df)
display(df.info())
# Out:
#                             Title                                 Price
# 0              A Light in the ...  £51.77\n\n In stock\n\nAdd to basket
# 1              Tipping the Velvet  £53.74\n\n In stock\n\nAdd to basket
# 2                      Soumission  £50.10\n\n In stock\n\nAdd to basket
# 3                   Sharp Objects  £47.82\n\n In stock\n\nAdd to basket
# 4    Sapiens: A Brief History ...  £54.23\n\n In stock\n\nAdd to basket
# ..                            ...                                   ...
# 63  Online Marketing for Busy ...  £46.35\n\n In stock\n\nAdd to basket
# 64            On a Midnight Clear  £14.07\n\n In stock\n\nAdd to basket
# 65              Obsidian (Lux #1)  £14.86\n\n In stock\n\nAdd to basket
# 66  My Paris Kitchen: Recipes ...  £33.37\n\n In stock\n\nAdd to basket
# 67                            NaN                                   NaN
#
# [68 rows x 2 columns]
# <class 'pandas.DataFrame'>
# RangeIndex: 68 entries, 0 to 67
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Title   65 non-null     str
#  1   Price   64 non-null     str
# dtypes: str(2)
# memory usage: 1.2 KB
# None

# %%
df["Price"] = df["Price"].str.extract(r"£(\d+\.\d+)").astype(float)
livro_barato = df[df['Price'] < 20]

# %%
display(df)
display(livro_barato)
# Out:
#                             Title  Price
# 0              A Light in the ...  51.77
# 1              Tipping the Velvet  53.74
# 2                      Soumission  50.10
# 3                   Sharp Objects  47.82
# 4    Sapiens: A Brief History ...  54.23
# ..                            ...    ...
# 63  Online Marketing for Busy ...  46.35
# 64            On a Midnight Clear  14.07
# 65              Obsidian (Lux #1)  14.86
# 66  My Paris Kitchen: Recipes ...  33.37
# 67                            NaN    NaN
#
# [68 rows x 2 columns]
#                                       Title  Price
# 7                   The Coming Woman: A ...  17.93
# 10    Starving Hearts (Triangular Trade ...  13.99
# 12                              Set Me Free  17.46
# 20                              In Her Wake  12.84
# 30               The Four Agreements: A ...  17.66
# 39   Untitled Collection: Sabbath Poems ...  14.27
# 41                           Unicorn Tracks  18.78
# 48           The Life-Changing Magic of ...  16.77
# 56   Princess Jellyfish 2-in-1 Omnibus, ...  13.61
# 57  Princess Between Worlds (Wide-Awake ...  13.34
# 58                  Pop Gun War, Volume ...  18.97
# 60                                 Patience  10.16
# 61                   Outcast, Vol. 1: A ...  15.44
# 64                      On a Midnight Clear  14.07
# 65                        Obsidian (Lux #1)  14.86

# %%
df = pd.DataFrame(livro_barato)
df.to_csv('livros_baratos.csv', index=False)
df = pd.read_csv('livros_baratos.csv')
display(df)
# Out:
#                                       Title  Price
# 0                   The Coming Woman: A ...  17.93
# 1     Starving Hearts (Triangular Trade ...  13.99
# 2                               Set Me Free  17.46
# 3                               In Her Wake  12.84
# 4                The Four Agreements: A ...  17.66
# 5    Untitled Collection: Sabbath Poems ...  14.27
# 6                            Unicorn Tracks  18.78
# 7            The Life-Changing Magic of ...  16.77
# 8    Princess Jellyfish 2-in-1 Omnibus, ...  13.61
# 9   Princess Between Worlds (Wide-Awake ...  13.34
# 10                  Pop Gun War, Volume ...  18.97
# 11                                 Patience  10.16
# 12                   Outcast, Vol. 1: A ...  15.44
# 13                      On a Midnight Clear  14.07
# 14                        Obsidian (Lux #1)  14.86

# %%
df = pd.read_csv('LIVROS_FILTRADOS.csv', sep=',')
display(df)
# Out:
#                                       Title  Price
# 0                   The Coming Woman: A ...  17.93
# 1     Starving Hearts (Triangular Trade ...  13.99
# 2                               Set Me Free  17.46
# 3                               In Her Wake  12.84
# 4                The Four Agreements: A ...  17.66
# 5    Untitled Collection: Sabbath Poems ...  14.27
# 6                            Unicorn Tracks  18.78
# 7            The Life-Changing Magic of ...  16.77
# 8    Princess Jellyfish 2-in-1 Omnibus, ...  13.61
# 9   Princess Between Worlds (Wide-Awake ...  13.34
# 10                  Pop Gun War, Volume ...  18.97
# 11                                 Patience  10.16
# 12                   Outcast, Vol. 1: A ...  15.44
# 13                      On a Midnight Clear  14.07
# 14                        Obsidian (Lux #1)  14.86
